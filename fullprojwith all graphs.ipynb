# %%
# %matplotlib notebook
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.patches as mpatches

# %%
# File to Load (Remember to change these)
filetoread = "inc_dt_region_vict.csv"
gender_age_filetoread = "gender_age.csv"


# Read the City and Ride Data
agegroup_df = pd.read_csv(gender_age_filetoread)




# Read the City and Ride Data
region_vict_df = pd.read_csv(filetoread)
agegroup_df.head()

region_vict_df.head()
# Out:
#    incident_id      date           state city_or_county  n_killed  n_injured
# 0       461105  1/1/2013    Pennsylvania     Mckeesport         0          4
# 1       460726  1/1/2013      California      Hawthorne         1          3
# 2       478855  1/1/2013            Ohio         Lorain         1          3
# 3       478925  1/5/2013        Colorado         Aurora         4          0
# 4       478959  1/7/2013  North Carolina     Greensboro         2          2

# %%
#Convert the data type of Date of Incident
region_vict_df['Date of Incident'] = pd.to_datetime(region_vict_df['date'], errors='coerce')
region_vict_df['Year'] = region_vict_df['Date of Incident'].dt.year
region_vict_df['Month'] = region_vict_df['Date of Incident'].dt.month
region_vict_df['Day'] = region_vict_df['Date of Incident'].dt.day
region_vict_df['casualty'] = region_vict_df['n_killed']+region_vict_df['n_injured']

#Convert the data type of Date of Incident
agegroup_df['Date of Incident'] = pd.to_datetime(agegroup_df['date'], errors='coerce')
agegroup_df['Year'] = agegroup_df['Date of Incident'].dt.year
agegroup_df['Month'] = agegroup_df['Date of Incident'].dt.month
agegroup_df['Day'] = agegroup_df['Date of Incident'].dt.day
agegroup_df['casualty'] = agegroup_df['n_killed']+agegroup_df['n_injured']

# %%
region_vict_df.head(12)
# Out:
#     incident_id       date           state city_or_county  n_killed  \
# 0        461105   1/1/2013    Pennsylvania     Mckeesport         0
# 1        460726   1/1/2013      California      Hawthorne         1
# 2        478855   1/1/2013            Ohio         Lorain         1
# 3        478925   1/5/2013        Colorado         Aurora         4
# 4        478959   1/7/2013  North Carolina     Greensboro         2
# 5        478948   1/7/2013        Oklahoma          Tulsa         4
# 6        479363  1/19/2013      New Mexico    Albuquerque         5
# 7        479374  1/21/2013       Louisiana    New Orleans         0
# 8        479389  1/21/2013      California      Brentwood         0
# 9        492151  1/23/2013        Maryland      Baltimore         1
# 10       491674  1/23/2013       Tennessee    Chattanooga         1
# 11       479413  1/25/2013        Missouri    Saint Louis         1
#
#     n_injured Date of Incident  Year  Month  Day  casualty
# ...

# %%
state_violence_df=region_vict_df.groupby(["Year","state"],as_index=False).agg({'incident_id':'count', 'casualty':'sum'})
state_violence_df=state_violence_df.set_index('Year')
state_violence_df.head()
# Out:
#             state  incident_id  casualty
# Year
# 2013      Alabama            2        12
# 2013      Arizona            5        24
# 2013   California           39       185
# 2013     Colorado            3        13
# 2013  Connecticut            3        15

# %%
yr2013_df = state_violence_df.loc[2013,["state","incident_id","casualty"]]
yr2013_df.head()
#x_2013_axis=[state for state in yr2013_df["state"]]
y_2013_axis =[casualty for casualty in yr2013_df["casualty"]]

yr2014_df = state_violence_df.loc[2014,["state","incident_id","casualty"]]
yr2014_df.head()
#x_2013_axis=[state for state in yr2014_df["state"]]
y_2014_axis =[casualty for casualty in yr2014_df["casualty"]]

yr2015_df = state_violence_df.loc[2015,["state","incident_id","casualty"]]
yr2015_df.head()
#x_2013_axis=[state for state in yr2015_df["state"]]
y_2015_axis =[casualty for casualty in yr2015_df["casualty"]]

yr2016_df = state_violence_df.loc[2016,["state","incident_id","casualty"]]
yr2016_df.head()
#x_2013_axis=[state for state in yr2016_df["state"]]
y_2016_axis =[casualty for casualty in yr2016_df["casualty"]]

yr2017_df = state_violence_df.loc[2017,["state","incident_id","casualty"]]
yr2017_df.head()
#x_2013_axis=[state for state in yr2016_df["state"]]
y_2017_axis =[casualty for casualty in yr2017_df["casualty"]]

yr2018_df = state_violence_df.loc[2018,["state","incident_id","casualty"]]
yr2018_df.head()
#x_2013_axis=[state for state in yr2016_df["state"]]
y_2018_axis =[casualty for casualty in yr2018_df["casualty"]]

# %%
# Set x axis and tick locations
x_2013_axis = np.arange(len(yr2013_df))
x_2014_axis = np.arange(len(yr2014_df))
x_2015_axis = np.arange(len(yr2015_df))
x_2016_axis = np.arange(len(yr2016_df))
x_2017_axis = np.arange(len(yr2017_df))
x_2018_axis = np.arange(len(yr2018_df))

tick_locations = [value for value in x_2013_axis]
tick_locations = [value for value in x_2014_axis]
tick_locations = [value for value in x_2015_axis]
tick_locations = [value for value in x_2016_axis]
tick_locations = [value for value in x_2017_axis]
tick_locations = [value for value in x_2018_axis]

plt.figure(figsize=(16,6))
plt.xlim(0,52)
plt.ylim(-40,6530)
plt.title("Casualty by State")
plt.xlabel("State")
plt.ylabel("Casualty")
plt.grid()

#plt.scatter(x_2013_axis, y_2013_axis,marker="o", alpha=.8,linewidths=1, color="coral",edgecolors='black',label="2013")
##plt.xticks(tick_locations, yr2013_df["state"], rotation="vertical")
#plt.scatter(x_2014_axis, y_2014_axis,marker="o", alpha=.8,linewidths=1, color="yellow",edgecolors='black',label="2014")
#plt.scatter(x_2015_axis, y_2015_axis,marker="o", alpha=.8,linewidths=1, color="lightblue", edgecolors='black',label="2015")
#plt.scatter(x_2016_axis, y_2016_axis,marker="o", alpha=.8,linewidths=1, color="teal", edgecolors='black',label="2016")
#plt.scatter(x_2017_axis, y_2017_axis,marker="o", alpha=.8,linewidths=1, color="lightgreen", edgecolors='black',label="2017")
#plt.scatter(x_2018_axis, y_2018_axis,marker="o", alpha=.8,linewidths=1, color="blue", edgecolors='black',label="2018")

plt.scatter(x_2013_axis, y_2013_axis,marker="o", alpha=.8,linewidths=1, color="coral",s=2*yr2013_df["casualty"], edgecolors='black',label="2013")
#plt.xticks(tick_locations, yr2013_df["state"], rotation="vertical")
plt.scatter(x_2014_axis, y_2014_axis,marker="o", alpha=.8,linewidths=1, color="yellow",s=2*yr2014_df["casualty"], edgecolors='black',label="2014")
plt.scatter(x_2015_axis, y_2015_axis,marker="o", alpha=.8,linewidths=1, color="lightblue",s=2*yr2015_df["casualty"], edgecolors='black',label="2015")
plt.scatter(x_2016_axis, y_2016_axis,marker="o", alpha=.8,linewidths=1, color="teal",s=2*yr2016_df["casualty"], edgecolors='black',label="2016")
plt.scatter(x_2017_axis, y_2017_axis,marker="o", alpha=.8,linewidths=1, color="lightgreen",s=2*yr2017_df["casualty"], edgecolors='black',label="2017")
plt.scatter(x_2018_axis, y_2018_axis,marker="o", alpha=.8,linewidths=1, color="blue",s=2*yr2018_df["casualty"], edgecolors='black',label="2018")


plt.xticks(tick_locations, yr2014_df["state"], rotation="vertical")




lgnd=plt.legend(loc='upper right',markerscale=.5,title="Year")
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]
lgnd.legendHandles[3]._sizes = [30]
lgnd.legendHandles[4]._sizes = [30]
lgnd.legendHandles[5]._sizes = [30]

#plt.figure(figsize=(16,4))
#plt.xlim(0,52)
#plt.ylim(0,330)
#3plt.title("Casualty by State")
#plt.xlabel("State")
#plt.ylabel("Casualty")
#plt.grid()




plt.savefig("Casualty By state Scatter.png")
# Out:
# <img src="data:image/png;base64,..." width="1152">

# %%
state_violence_df.head()
# Out:
#             state  incident_id  casualty
# Year
# 2013      Alabama            2        12
# 2013      Arizona            5        24
# 2013   California           39       185
# 2013     Colorado            3        13
# 2013  Connecticut            3        15

# %%
fig, ax = plt.subplots()
stacked_frame=state_violence_df.groupby(['state', 'Year'])['casualty'].first().unstack().plot(kind='bar',width=1,edgecolor='black', stacked=True,figsize = (18,10),ax=ax)
ax.grid()
plt.title("Casualties By State per Year")
plt.xlabel("State")
plt.ylabel("Casualty")
# Out:
# Text(0, 0.5, 'Casualty')

# %%
fig = stacked_frame.get_figure()
fig.savefig("Casualty By state stackedbar.png")

# %%
city_violence_df=region_vict_df.groupby(["Year",'state',"city_or_county"]).agg({'incident_id':'count', 'casualty':'sum'})
#,as_index=False
city_violence_df.head()
#city_violence_df.to_csv("cityviotest.csv",index="False")
# Out:
#                               incident_id  casualty
# Year state   city_or_county
# 2013 Alabama Florence                   1         4
#              Montgomery                 1         8
#      Arizona Apache Junction            1         5
#              Avondale                   1         4
#              Phoenix                    3        15

# %%
# building least adn worst gun violence prone cities by each year


year_city_vio_df=city_violence_df.loc[2013,["incident_id","casualty"]]
year_city_vio_df["Year"]=2013
year_city_vio_df["incident_id"]=year_city_vio_df["incident_id"].astype(int)
year_city_vio_df["casualty"]=year_city_vio_df["casualty"].astype(int)
year_city_vio_df=year_city_vio_df.reset_index()
year_city_vio_df=year_city_vio_df.sort_values(by=["incident_id","casualty"], ascending=False)
year_city_vio_df=year_city_vio_df.reset_index()
worst2013_city=year_city_vio_df.iloc[[0,1,2,3,4]]
best2013_city=year_city_vio_df.iloc[[-1,-2,-3,-4,-5]]

year_city_vio_df=city_violence_df.loc[2014,["incident_id","casualty"]]
year_city_vio_df["Year"]=2014
year_city_vio_df["incident_id"]=year_city_vio_df["incident_id"].astype(int)
year_city_vio_df["casualty"]=year_city_vio_df["casualty"].astype(int)
year_city_vio_df=year_city_vio_df.reset_index()
year_city_vio_df=year_city_vio_df.sort_values(by=["incident_id","casualty"], ascending=False)
year_city_vio_df=year_city_vio_df.reset_index()
worst2014_city=year_city_vio_df.iloc[[0,1,2,3,4]]
best2014_city=year_city_vio_df.iloc[[-1,-2,-3,-4,-5]]


year_city_vio_df=city_violence_df.loc[2015,["incident_id","casualty"]]
year_city_vio_df["Year"]=2015
year_city_vio_df["incident_id"]=year_city_vio_df["incident_id"].astype(int)
year_city_vio_df["casualty"]=year_city_vio_df["casualty"].astype(int)
year_city_vio_df=year_city_vio_df.reset_index()
year_city_vio_df=year_city_vio_df.sort_values(by=["incident_id","casualty"], ascending=False)
year_city_vio_df=year_city_vio_df.reset_index()
worst2015_city=year_city_vio_df.iloc[[0,1,2,3,4]]
best2015_city=year_city_vio_df.iloc[[-1,-2,-3,-4,-5]]


year_city_vio_df=city_violence_df.loc[2016,["incident_id","casualty"]]
year_city_vio_df["Year"]=2016
year_city_vio_df["incident_id"]=year_city_vio_df["incident_id"].astype(int)
year_city_vio_df["casualty"]=year_city_vio_df["casualty"].astype(int)
year_city_vio_df=year_city_vio_df.reset_index()
year_city_vio_df=year_city_vio_df.sort_values(by=["incident_id","casualty"], ascending=False)
year_city_vio_df=year_city_vio_df.reset_index()
worst2016_city=year_city_vio_df.iloc[[0,1,2,3,4]]
best2016_city=year_city_vio_df.iloc[[-1,-2,-3,-4,-5]]

year_city_vio_df=city_violence_df.loc[2017,["incident_id","casualty"]]
year_city_vio_df["Year"]=2017
year_city_vio_df["incident_id"]=year_city_vio_df["incident_id"].astype(int)
year_city_vio_df["casualty"]=year_city_vio_df["casualty"].astype(int)
year_city_vio_df=year_city_vio_df.reset_index()
year_city_vio_df=year_city_vio_df.sort_values(by=["incident_id","casualty"], ascending=False)
year_city_vio_df=year_city_vio_df.reset_index()
worst2017_city=year_city_vio_df.iloc[[0,1,2,3,4]]
best2017_city=year_city_vio_df.iloc[[-1,-2,-3,-4,-5]]

year_city_vio_df=city_violence_df.loc[2018,["incident_id","casualty"]]
year_city_vio_df["Year"]=2018
year_city_vio_df["incident_id"]=year_city_vio_df["incident_id"].astype(int)
year_city_vio_df["casualty"]=year_city_vio_df["casualty"].astype(int)
year_city_vio_df=year_city_vio_df.reset_index()
year_city_vio_df=year_city_vio_df.sort_values(by=["incident_id","casualty"], ascending=False)
year_city_vio_df=year_city_vio_df.reset_index()
worst2018_city=year_city_vio_df.iloc[[0,1,2,3,4]]
best2018_city=year_city_vio_df.iloc[[-1,-2,-3,-4,-5]]



#worst2014_city.head()
#best2018_city.head()
#year_city_vio_df.head(10)
#year_city_vio_df.columns

worst_city_concat_df=pd.concat([worst2013_city,worst2014_city,worst2015_city,worst2016_city,worst2017_city,worst2018_city])
best_city_concat_df=pd.concat([best2013_city,best2014_city,best2015_city,best2016_city,best2017_city,best2018_city])
worst_city_concat_df.head(30)
best_city_concat_df.head(30)
# Out:
#       index         state               city_or_county  incident_id  casualty  \
# 180     146  Pennsylvania                 Wilkes Barre            1         1
# 179     139  Pennsylvania                        Derry            1         1
# 178     110      New York                Locust Valley            1         1
# 177     109      New York                      Jamaica            1         1
# 176     102    New Jersey                   Tabernacle            1         1
# 7512   7507       Wyoming                       Powell            1         0
# 7511   7506       Wyoming                     Pinedale            1         0
# 7510   7505       Wyoming                    Pavillion            1         0
# 7509   7502       Wyoming                        Moose            1         0
# 7508   7501       Wyoming                 Medicine Bow            1         0
# 7969   7965       Wyoming                 Rock Springs            1         0
# ...

# %%
#graph plotinng 
#worst_city_concat_df=worst_city_concat_df.reset_index()

#tick_locations = [value+0.4 for value in x_axis]
#worst_city_concat_df=worst_city_concat_df.set_index("Year")
worst_city_grp_df=worst_city_concat_df.groupby("Year")["casualty"].sum().reset_index().rename(columns={"Year":"Year",'casualty':"Total Casualty"})
#x_axis = worst_city_grp_df['Year']
#y_axis = 

worst_city_grp_df.head()

#plt.figure(figsize=(10,10))
plt.plot(worst_city_grp_df["Year"],worst_city_grp_df["Total Casualty"] , color='r')#, alpha=0.5, align="edge")
#plt.xticks(tick_locations, rain_df["State"], rotation="vertical")

# %%
##remove the index column from above 
del worst_city_concat_df['index']
del best_city_concat_df['index']
worst_city_concat_df.head()
# Out:
#                   state city_or_county  incident_id  casualty  Year
# 0              Illinois        Chicago           15        77  2013
# 1          Pennsylvania   Philadelphia            9        29  2013
# 2              New York       Brooklyn            8        41  2013
# 3  District of Columbia     Washington            5        30  2013
# 4              Missouri    Kansas City            5        26  2013

# %%
#subplot s by year for the worst cities showing high gun violence
clist=['b', 'g', 'r', 'c', 'm']  # set colors
fig = plt.figure()
fig.set_figheight(18)
fig.set_figwidth(18)
ax = fig.add_subplot(231)
#plt.plot(x,y)
worst_city_concat_df.set_index('Year',inplace=True)
#x_axis = [index for index in worst_city_concat_df.index.unique()]#np.arange(len(worst_city_concat_df)+1)
#tick_locations = [value+0.6 for value in x_axis]
citynames=[]
cas_numbers=[]
citynames=[city for city in worst_city_concat_df.loc[2013,'city_or_county']]
cas_numbers =[ numbers for numbers in worst_city_concat_df.loc[2013,'casualty']]
plt.bar(citynames,cas_numbers, color=clist, alpha=0.5, align="center",width=.5)
plt.title("Gun Violence-Top 5 Cities For Year 2013 ")
plt.ylabel("Casualties(Killed/Injured)")
plt.xlabel("CityNames")
plt.xticks(rotation=45)

ax = fig.add_subplot(232)
x_axis = [index for index in worst_city_concat_df.index.unique()]#np.arange(len(worst_city_concat_df)+1)
tick_locations = [value+0.6 for value in x_axis]
citynames=[]
cas_numbers=[]
citynames=[city for city in worst_city_concat_df.loc[2014,'city_or_county']]
cas_numbers =[ numbers for numbers in worst_city_concat_df.loc[2014,'casualty']]
plt.bar(citynames,cas_numbers, color=clist, alpha=0.5, align="center",width=.5)
plt.title("Gun Violence-Top 5 Cities For Year 2014 ")
plt.ylabel("Casualties(Killed/Injured)")
plt.xlabel("CityNames")
plt.xticks(rotation=45)

ax = fig.add_subplot(233)
x_axis = [index for index in worst_city_concat_df.index.unique()]#np.arange(len(worst_city_concat_df)+1)
tick_locations = [value+0.6 for value in x_axis]
citynames=[]
cas_numbers=[]
citynames=[city for city in worst_city_concat_df.loc[2015,'city_or_county']]
cas_numbers =[ numbers for numbers in worst_city_concat_df.loc[2015,'casualty']]
plt.bar(citynames,cas_numbers, color=clist, alpha=0.5, align="center",width=.5)
plt.title("Gun Violence-Top 5 Cities For Year 2015 ")
plt.ylabel("Casualties(Killed/Injured)")
plt.xlabel("CityNames")
plt.xticks(rotation=45)

ax = fig.add_subplot(234)
x_axis = [index for index in worst_city_concat_df.index.unique()]#np.arange(len(worst_city_concat_df)+1)
tick_locations = [value+0.6 for value in x_axis]
citynames=[]
cas_numbers=[]
citynames=[city for city in worst_city_concat_df.loc[2016,'city_or_county']]
cas_numbers =[ numbers for numbers in worst_city_concat_df.loc[2016,'casualty']]
plt.bar(citynames,cas_numbers, color=clist, alpha=0.5, align="center",width=.5)
plt.title("Gun Violence-Top 5 Cities For Year 2016 ")
plt.ylabel("Casualties(Killed/Injured)")
plt.xlabel("CityNames")
plt.xticks(rotation=45)

ax = fig.add_subplot(235)
x_axis = [index for index in worst_city_concat_df.index.unique()]#np.arange(len(worst_city_concat_df)+1)
tick_locations = [value+0.6 for value in x_axis]
citynames=[]
cas_numbers=[]
citynames=[city for city in worst_city_concat_df.loc[2017,'city_or_county']]
cas_numbers =[ numbers for numbers in worst_city_concat_df.loc[2017,'casualty']]
plt.bar(citynames,cas_numbers, color=clist, alpha=0.5, align="center",width=.5)
plt.title("Gun Violence-Top 5 Cities For Year 2017 ")
plt.ylabel("Casualties(Killed/Injured)")
plt.xlabel("CityNames")
plt.xticks(rotation=45)

ax = fig.add_subplot(236)
x_axis = [index for index in worst_city_concat_df.index.unique()]#np.arange(len(worst_city_concat_df)+1)
tick_locations = [value+0.6 for value in x_axis]
citynames=[]
cas_numbers=[]
citynames=[city for city in worst_city_concat_df.loc[2018,'city_or_county']]
cas_numbers =[ numbers for numbers in worst_city_concat_df.loc[2018,'casualty']]
plt.bar(citynames,cas_numbers, color=clist, alpha=0.5, align="center",width=.5)
plt.title("Gun Violence-Top 5 Cities For Year 2018 ")
plt.ylabel("Casualties(Killed/Injured)")
plt.xlabel("CityNames")
plt.xticks(rotation=45)
plt.savefig("subplot 5 worst cities.png")
#plt.xticks(tick_locations, [city for city in citynames], rotation="horizontal")
plt.show()

# %%
gr_casualty_wrstcity_df=worst_city_concat_df
#del gr_casualty_wrstcity_df["index"]
#del gr_casualty_wrstcity_df["state"]
del gr_casualty_wrstcity_df["incident_id"]
#del gr_casualty_wrstcity_df["level_0"]
gr_casualty_wrstcity_df.head()
worst_city_concat_df.head()
#,"state","incdent_id"]
# Out:
#                      state city_or_county  casualty
# Year
# 2013              Illinois        Chicago        77
# 2013          Pennsylvania   Philadelphia        29
# 2013              New York       Brooklyn        41
# 2013  District of Columbia     Washington        30
# 2013              Missouri    Kansas City        26

# %%
#plt.figure(figsize=(10,10))
#worst_city_concat_df.pivot(index='Year', columns='city_or_county').plot(kind='bar',rot=0)
###ax_df=worst_city_concat_df.pivot(index=worst_city_concat_df.index, columns='city_or_county').plot.bar(rot=1,subplots=False,Width=.15,edgecolor='black',position=0,legend='city_or_county',figsize=(12,9),align="center",sort_columns=True)
ax_df=worst_city_concat_df.pivot_table(index='Year', columns='city_or_county',values=['casualty'])
ax_df.head()
# Out:
#                 casualty                                                \
# city_or_county Baltimore Brooklyn Chicago Detroit Houston Jacksonville
# Year
# 2013                 NaN     41.0    77.0     NaN     NaN          NaN
# 2014               614.0      NaN  2307.0     NaN     NaN          NaN
# 2015               877.0      NaN  2771.0     NaN   541.0          NaN
# 2016               846.0      NaN  3553.0     NaN     NaN        350.0
# 2017               955.0      NaN  3304.0     NaN     NaN        424.0
#
#                                                                        \
# city_or_county Kansas City Memphis Milwaukee New Orleans Philadelphia
# Year
# 2013                  26.0     NaN       NaN         NaN         29.0
# 2014                   NaN     NaN       NaN       594.0       1025.0
# 2015                   NaN     NaN       NaN       547.0          NaN
# 2016                   NaN   651.0       NaN       666.0          NaN
# ...

# %%
ax_df.plot.bar(rot=1,subplots=False,Width=.15,edgecolor='black',colormap='Paired',position=0,legend='city_or_county',figsize=(12,9),align="center",sort_columns=True)


#ax_df.plot.bar(rot=0,subplots=False,legend='')
plt.title("Gun Violence-Top 5 Cities ")

plt.ylabel("Casualties(Killed/Injured)")
lgnd=plt.legend(loc='upper right',markerscale=.5,title="city_or_county")
#plt.figure(figsize=(10,10))

plt.savefig("5 worst cities.png")
plt.show()

# %%
bins = [0, 9, 19, 29, 39, 49,59,69,100]
#work_pur_grp=work_pur_grp.rename(columns={"Purchase ID":"Purchase Count"})
#agegroup_df=agegroup_df.rename({'incident_id':'incidents'})

group_names = ["<10", "10-19", "20-29", "30-39", "40-49", "50-59", "60-69","70+"]
agegroup_df["age"] = pd.cut(agegroup_df["age"], bins, labels=group_names)
agegroup_df.head()
# Out:
#    Unnamed: 0  part_age_cnt    age  incident_id      date         state  \
# 0           0             0  20-29       461105  1/1/2013  Pennsylvania
# 1           1             0  20-29       460726  1/1/2013    California
# 2           2             0  20-29       478855  1/1/2013          Ohio
# 3           3             1  30-39       478855  1/1/2013          Ohio
# 4           4             2  30-39       478855  1/1/2013          Ohio
#
#   city_or_county  n_killed  n_injured  gender_cnt gender Date of Incident  \
# 0     Mckeesport         0        4.0           0   Male       2013-01-01
# 1      Hawthorne         1        3.0           0   Male       2013-01-01
# 2         Lorain         1        3.0           0   Male       2013-01-01
# 3         Lorain         1        3.0           1   Male       2013-01-01
# 4         Lorain         1        3.0           2   Male       2013-01-01
#
#    Year  Month  Day  casualty
# 0  2013      1    1       4.0
# ...

# %%
agegroup_df.head()
# Out:
#    Unnamed: 0  part_age_cnt    age  incident_id      date         state  \
# 0           0             0  20-29       461105  1/1/2013  Pennsylvania
# 1           1             0  20-29       460726  1/1/2013    California
# 2           2             0  20-29       478855  1/1/2013          Ohio
# 3           3             1  30-39       478855  1/1/2013          Ohio
# 4           4             2  30-39       478855  1/1/2013          Ohio
#
#   city_or_county  n_killed  n_injured  gender_cnt gender Date of Incident  \
# 0     Mckeesport         0        4.0           0   Male       2013-01-01
# 1      Hawthorne         1        3.0           0   Male       2013-01-01
# 2         Lorain         1        3.0           0   Male       2013-01-01
# 3         Lorain         1        3.0           1   Male       2013-01-01
# 4         Lorain         1        3.0           2   Male       2013-01-01
#
#    Year  Month  Day  casualty
# 0  2013      1    1       4.0
# ...

# %%
agegroup_grp=agegroup_df.groupby(["Year","age"],as_index=False)["incident_id"].count()
agegroup_grp=agegroup_grp.rename(columns={'incident_id':'incidents'})
agegroup_grp.head()
# Out:
#    Year    age  incidents
# 0  2013    <10         20
# 1  2013  10-19        232
# 2  2013  20-29        353
# 3  2013  30-39        118
# 4  2013  40-49         60

# %%
ax_df=agegroup_grp.pivot_table(index='Year', columns='age',values=['incidents'])

ax_df.head()
# Out:
#      incidents
# age        <10  10-19  20-29  30-39 40-49 50-59 60-69  70+
# Year
# 2013        20    232    353    118    60    36    33    9
# 2014       589   8119  16553   7447  3712  2296   976  698
# 2015       627   9484  20372   9593  4536  2782  1180  664
# 2016       578  10771  22829  11350  5157  2912  1271  683
# 2017       573  10923  22338  11756  5300  2967  1397  649

# %%
ax_df.plot.bar(rot=1,subplots=False,Width=.25,edgecolor='black',stacked=True,colormap='Paired',position=0,legend='',figsize=(12,9),sort_columns=True)
plt.title("Total Incidents By Age Group Each year ")

plt.ylabel("Total Incidents")

#red_patch = mpatches.Patch(color='red', label='The red data')
#plt.legend(handles=[red_patch])
lgnd=plt.legend(loc='upper right',markerscale=.5,title="Incidents by Age Group")
print(lgnd.legendHandles[2]._label)
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]
lgnd.legendHandles[3]._sizes = [30]
lgnd.legendHandles[4]._sizes = [30]
lgnd.legendHandles[5]._sizes = [30]
lgnd.legendHandles[6]._sizes = [30]
plt.savefig("stacked for age group.png")
# Out:
# _nolegend_

# %%
ax_df.plot.bar(rot=1,subplots=False,Width=.25,edgecolor='black',stacked=False,colormap='Paired',position=0,legend='Age groups Involved',figsize=(12,9),sort_columns=True)
plt.savefig("unstacked for age group.png")
